# %%
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
N = 4000

# %%
x = np.random.random(size = N)*100
y = np.random.random(size = N)*100
radii = np.random.random(size = N)*1.5
colors = ['#%02x%02x%02x' % (r,g,150) for r,g in zip(np.floor(50+2*x),np.floor(30+2*y))]

# %%
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="53b8eb3a-8b10-4516-afe1-71cd1bd8680a">Loading BokehJS ...</span>
#     </div>

# %%
p = figure()
p.circle(x,y, radius = radii,fill_color = colors, fill_alpha = 0.6,line_color = None)

# %%
show(p)
# Out:
#     <div class="plotdiv" id="d0aa13fb-1039-4681-a5c1-6e74b60b387c"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d0aa13fb-1039-4681-a5c1-6e74b60b387c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd0aa13fb-1039-4681-a5c1-6e74b60b387c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a62d4281-b9b4-4e5a-9f03-5279d078840a":{"roots":{"references":[{"attributes":{"data_source":{"id":"c09e537e-4776-4e5f-b1b7-36f09f618ee1","type":"ColumnDataSource"},"glyph":{"id":"afd30dbf-2d9e-4148-bf14-589cc034c8c8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"e97d919e-e831-4886-9f06-f5b9580374fb","type":"Circle"},"selection_glyph":null},"id":"878688c5-7cdd-4874-8f50-65d76f3840fc","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"ba896f56-4554-492c-a4a3-b96e32d85fb6","type":"BasicTickFormatter"},"plot":{"id":"cef5d986-cf02-4ee4-a3f7-3d9eaed2f4b5","subtype":"Figure","type":"Plot"},"ticker":{"id":"dede3009-a529-40f3-8f3d-c1dd83af399c","type":"BasicTicker"}},"id":"a5946a92-e157-4b9e-9b84-96ce2b2d6fdd","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e97d919e-e831-4886-9f06-f5b9580374fb","type":"Circle"},{"attributes":{},"id":"dede3009-a529-40f3-8f3d-c1dd83af399c","type":"BasicTicker"},{"attributes":{"plot":{"id":"cef5d986-cf02-4ee4-a3f7-3d9eaed2f4b5","subtype":"Figure","type":"Plot"}},"id":"364b76d3-df4b-404c-a2d4-88d7bfc2e4e2","type":"ResizeTool"},{"attributes":{"callback":null},"id":"0fbe4cce-8b5d-45a2-abf4-a7b76c629c8c","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["radius","y","x","fill_color"],"data":{"fill_color":["#c64096","#499796","#94db96","#4dd896","#abc796","#be8e96","#d09096","#a79c96","#cb3796","#6d8896","#52a096","#806296","#d65a96","#8ad796","#d64996","#b17b96","#387496","#f46a96","#89c196","#e46596","#b8dd96","#476796","#527396","#60e596","#447996","#edb696","#463996","#593e96","#435096","#892a96","#868496","#5a6896","#995e96","#3f9996","#b34296","#ca3