# %%
#Enter the location of the QUALTX output file
QUALTXoutfile = r'C:\Users\Ernest\Ernest_Sandbox\TurboQUALTX\TurboQUALTX\RB55NOV.OUT'

# %%
#Import python packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import os
import ET_Utils.QUALTX_Utils
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4708e2c2-f727-434f-86fd-312a536a9b19">Loading BokehJS ...</span>
#     </div>

# %%
#Parse the QUALTX output file 
Scenario = QUALTXoutfile
DOstds = [5,4.8]
WQC_of_interest = ['DO_MG/L','BOD_MG/L','NH3_MG/L','NO3+2_MG/L','PHOS_MG/L']
StreamNames, Rdf, Hdf, AllWQdf = ET_Utils.QUALTX_Utils.Process_QUALTX(QUALTXoutfile,
                                                                      Scenario,DOstds = DOstds,
                                                                      WQC_of_interest = WQC_of_interest,
                                                                      loc = 1,plot_pdf = 0)
# Out:
# PECAN_LITTLE ELM CR
# OUTFALL 001 COVE
# OUTFALL 002 TRIB

# %%
#Perform plotting
y_label = 'Concentration (mg/L)'
x_label = 'Distance (km)'

#Determine range of y-axis
maxy = []
for tempWQC in WQC_of_interest:
    maxy.append(max(AllWQdf[tempWQC]))
y_range = [0,round(max(maxy)*1.5)]

#Set line width
lws = np.zeros(len(WQC_of_interest))+2

#Set line colors
plot_colors = ['blue','black','green','cyan','orange']

#Set line symbols
plot_symbols = ['-','-','-','-','-']

#Set marker sizes
markersizes = np.zeros(len(WQC_of_interest))+1

#Set label sizes
x_labelsize = 15
y_labelsize = 15

# %%
# Loop through each stream and plot the WQ profile plot
#TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select"
#TOOLS = [BoxSelectTool(), HoverTool()]
TOOLS="hover"
    
#output_file("legend.html", title="legend.py example")

#show(vplot(p1, p2))  # open a browser

for StreamName in StreamNames:
    WQdf = AllWQdf[AllWQdf['Stream']==StreamName].copy()
    SRdf = Rdf[Rdf['StreamName']==StreamName].reset_index()
    x_range = [max(WQdf['ENDING_DIST'])*1.025,min(WQdf['ENDING_DIST'])]
    p = figure(title=StreamName, tools=TOOLS,x_range = x_range,y_range=y_range,plot_width=900, plot_height=450)  
    if StreamName == StreamNames[0]:
        hover = p.select(dict(type=HoverTool))
        hover.tooltips = [
            # add to this
            ("Conc ", "$y mg/L"),
        ]    
    p.xaxis.axis_label = x_label
    p.yaxis.axis_label = y_label

    
    for k in range(0,len(WQC_of_interest)):        
        #ls.append(ax.plot(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]),plot_symbols[k], 
        #lw = lws[k],markersize=markersizes[k],
        #                  color = plot_colors[k],label = WQC_of_interest[k]))
        # add a line renderer
        p.line(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]), 
               legend=WQC_of_interest[k], line_width= lws[k],
               color = plot_colors[k],name = WQC_of_interest[k])

         #Overplot reach start and end points of each reach
        if len(SRdf) > 0:
            Points1 = list(SRdf['BEGIN NAME'])
            Rkms1 = list(SRdf['BEGIN REACH KM'])
            if len(SRdf) > 1:
                Points2 = [SRdf['END NAME'][SRdf.index[-1]]]
                Rkms2 = [SRdf['END REACH KM'][SRdf.index[-1]]]
            else:
                Points2 = list(SRdf['END NAME'])
                Rkms2 = list(SRdf['END REACH KM'])
                
            Points = Points1 + Points2
        
            #Rkms = Rkms1.append(Rkms2)
            Rkms = Rkms1+Rkms2
        #p1.text([65,65,65],[65,65,65], text=[ str(i) for i in x], alpha=0.5, text_font_size="5pt", text_baseline="middle", 
        #text_align="center")
            for i in range(0,len(Points)):
                #print Points[i]
                p.line([Rkms[i],Rkms[i]],y_range,'..',color = 'grey')
                p.text([Rkms[i]],[np.mean(y_range)],text = [Points[i]],text_align = 'center',
                       angle = 3.14159265/2,text_font_size = '9pt',text_color = 'grey')
                
        
        if len(DOstds) > 0:
            for DOstd in DOstds:
                p.line(x_range,[DOstd,DOstd],'..',color = 'red')
                #print DOstd
                p.text([np.mean(x_range)],[DOstd],text = ["DO std = "+"{:4.1f}".format(DOstd)+" mg/L"],
                       text_font_size = '9pt',text_color = 'red')
                #p.text(np.mean(x_range),DOstd,"DO std = Monkey mg/L")

        p.xgrid.grid_line_color = None
        p.ygrid.grid_line_color = None
    show(p)
# Out:
#     <div class="plotdiv" id="3a0b72e6-bbe5-481a-b9db-4fb9e7573358"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3a0b72e6-bbe5-481a-b9db-4fb9e7573358");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3a0b72e6-bbe5-481a-b9db-4fb9e7573358' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c5bb32b6-0b6b-4169-8589-1e7d9e181b1f":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.48","2.48"],"y":[0.0,13.0]}},"id":"3b288a1f-c560-48e0-bf2f-a546576c9366","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".12",".12"],"y":[0.0,13.0]}},"id":"cec023e4-91c9-474b-8f49-3bf18f0319c2","type":"ColumnDataSource"},{"attributes":{"line_color":{"field":"r"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69ed741b-336c-4a03-b860-b2753f47615a","type":"Line"},{"attributes":{"text_color":{"field":"r"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d1975be-d78c-4fbf-827f-4702d62e78e5","type":"Text"},{"attributes":{"data_source":{"id":"59efc433-e6ca-44be-8e85-65d542049c96","type":"ColumnDataSource"},"glyph":{"id":"f94b8240-d736-4230-b965-e794790e74b4","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"eac2c2a1-2099-46db-b3f6-89ae220a101c","type":"Text"},"selection_glyph":null},"id":"7abc25e1-0530-4e32-90b9-9520bfa99bc3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".40",".40"],"y":[0.0,13.0]}},"id":"6052ed67-8952-4720-a71c-256596ca5cad","type":"ColumnDataSource"},{"attributes":{"angle":{"units":"rad","value":1.570796325},"text_align":"center","text_color":{"value":"grey"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"397ad84e-c311-4f63-ba81-ae2a0cff728d","type":"Text"},{"attributes":{"callback":null,"column_names":["y","text","x"],"data":{"text":["DO std =  5.0 mg/L"],"x":[1.2735625],"y":[5]}},"id":"90d0381b-c62a-4373-9282-8056539ecae0","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e858a54-f4d6-4629-9c58-cb4f32cd1fa8","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea317efc-9266-466e-a5eb-f5f6bdfc5ef1","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.29","2.29"],"y":[0.0,13.0]}},"id":"1c5a8e14-523a-48f4-9d97-7888f1928811","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"927652aa-c610-4fa4-a8a2-8c55eddf3fe5","type":"Line"},{"attributes":{"data_source":{"id":"559924a3-e1a0-4e71-8a47-c073f8fd3a4b","type":"ColumnDataSource"},"glyph":{"id":"22314389-8a64-48d4-bce8-91131cb0ba2d","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"ee4e224a-1f75-4ee5-a000-497ce83f3e77","type":"Text"},"selection_glyph":null},"id":"3c51aff4-e298-4921-8f27-2871621310c3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["KM 2.285"],"x":["2.29"],"y":[6.5]}},"id":"a3f8cf83-e7f4-45f8-8109-d326a50840ef","type":"ColumnDataSource"},{"attributes":{"text_color":{"value":"red"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2ee5d1a-59af-45b8-8624-90ffb63176f6","type":"Text"},{"attributes":{"data_source":{"id":"3c9d9873-77a7-47a5-9e2c-0e6ec817e1af","type":"ColumnDataSource"},"glyph":{"id":"c4e7edc5-b42e-400c-8a27-e41b1b12cf2e","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"74db4964-6b57-460a-a666-073d5a40fbb6","type":"Text"},"selection_glyph":null},"id":"a869a69c-37b1-4d52-8e22-11103f5f124b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.49","2.49"],"y":[0.0,13.0]}},"id":"6fa12931-6b25-46fd-a918-78e7a9c11952","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d8952ab8-a922-4104-9be4-cac7a16a3fb1","type":"ColumnDataSource"},"glyph":{"id":"b4e382d7-3c75-48e2-96c7-9874b2ccb5d9","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"c62411ce-5f08-442e-893c-c0f4fe7786e4","type":"Text"},"selection_glyph":null},"id":"a6b40315-6ec9-4979-8e75 ...
#     <div class="plotdiv" id="a0beb676-24b3-4ede-ab18-0d2ac193e845"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a0beb676-24b3-4ede-ab18-0d2ac193e845");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a0beb676-24b3-4ede-ab18-0d2ac193e845' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"ba61de28-2dd1-4e0b-9453-99d399308b42":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.29","2.29"],"y":[0.0,13.0]}},"id":"1c5a8e14-523a-48f4-9d97-7888f1928811","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".12",".12"],"y":[0.0,13.0]}},"id":"cec023e4-91c9-474b-8f49-3bf18f0319c2","type":"ColumnDataSource"},{"attributes":{"line_color":{"field":"r"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69ed741b-336c-4a03-b860-b2753f47615a","type":"Line"},{"attributes":{"text_color":{"field":"r"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d1975be-d78c-4fbf-827f-4702d62e78e5","type":"Text"},{"attributes":{"data_source":{"id":"59efc433-e6ca-44be-8e85-65d542049c96","type":"ColumnDataSource"},"glyph":{"id":"f94b8240-d736-4230-b965-e794790e74b4","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"eac2c2a1-2099-46db-b3f6-89ae220a101c","type":"Text"},"selection_glyph":null},"id":"7abc25e1-0530-4e32-90b9-9520bfa99bc3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".40",".40"],"y":[0.0,13.0]}},"id":"6052ed67-8952-4720-a71c-256596ca5cad","type":"ColumnDataSource"},{"attributes":{"angle":{"units":"rad","value":1.570796325},"text_align":"center","text_color":{"value":"grey"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"397ad84e-c311-4f63-ba81-ae2a0cff728d","type":"Text"},{"attributes":{"callback":null,"column_names":["y","text","x"],"data":{"text":["DO std =  5.0 mg/L"],"x":[1.2735625],"y":[5]}},"id":"90d0381b-c62a-4373-9282-8056539ecae0","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e858a54-f4d6-4629-9c58-cb4f32cd1fa8","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea317efc-9266-466e-a5eb-f5f6bdfc5ef1","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.48","2.48"],"y":[0.0,13.0]}},"id":"3b288a1f-c560-48e0-bf2f-a546576c9366","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"927652aa-c610-4fa4-a8a2-8c55eddf3fe5","type":"Line"},{"attributes":{"data_source":{"id":"559924a3-e1a0-4e71-8a47-c073f8fd3a4b","type":"ColumnDataSource"},"glyph":{"id":"22314389-8a64-48d4-bce8-91131cb0ba2d","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"ee4e224a-1f75-4ee5-a000-497ce83f3e77","type":"Text"},"selection_glyph":null},"id":"3c51aff4-e298-4921-8f27-2871621310c3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["KM 2.285"],"x":["2.29"],"y":[6.5]}},"id":"a3f8cf83-e7f4-45f8-8109-d326a50840ef","type":"ColumnDataSource"},{"attributes":{"text_color":{"value":"red"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2ee5d1a-59af-45b8-8624-90ffb63176f6","type":"Text"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.20","1.20"],"y":[0.0,13.0]}},"id":"38f22d39-d817-4b28-a742-514c120d138f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3c9d9873-77a7-47a5-9e2c-0e6ec817e1af","type":"ColumnDataSource"},"glyph":{"id":"c4e7edc5-b42e-400c-8a27-e41b1b12cf2e","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"74db4964-6b57-460a-a666-073d5a40fbb6","type":"Text"},"selection_glyph":null},"id":"a869a69c-37b1-4d52-8e22-11103f5f124b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","text","x"],"data":{"text":["DO std =  4.8 mg/L"],"x":[0.0],"y":[4.8]}},"id":"19e67279-2bf8-484b-84e5-8c90ba98e81e","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.49","2.49"],"y":[0.0,13.0]}},"id":"6fa12931-6b25-46fd-a9 ...
#     <div class="plotdiv" id="1e3a597b-b7bc-4331-8b2f-34fd5fa9554a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1e3a597b-b7bc-4331-8b2f-34fd5fa9554a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1e3a597b-b7bc-4331-8b2f-34fd5fa9554a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"14657593-3db2-48d0-b05d-6d48e249bb3c":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.48","2.48"],"y":[0.0,13.0]}},"id":"3b288a1f-c560-48e0-bf2f-a546576c9366","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".12",".12"],"y":[0.0,13.0]}},"id":"cec023e4-91c9-474b-8f49-3bf18f0319c2","type":"ColumnDataSource"},{"attributes":{"line_color":{"field":"r"},"x":{"field":"x"},"y":{"field":"y"}},"id":"69ed741b-336c-4a03-b860-b2753f47615a","type":"Line"},{"attributes":{"text_color":{"field":"r"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8d1975be-d78c-4fbf-827f-4702d62e78e5","type":"Text"},{"attributes":{"data_source":{"id":"59efc433-e6ca-44be-8e85-65d542049c96","type":"ColumnDataSource"},"glyph":{"id":"f94b8240-d736-4230-b965-e794790e74b4","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"eac2c2a1-2099-46db-b3f6-89ae220a101c","type":"Text"},"selection_glyph":null},"id":"7abc25e1-0530-4e32-90b9-9520bfa99bc3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".40",".40"],"y":[0.0,13.0]}},"id":"6052ed67-8952-4720-a71c-256596ca5cad","type":"ColumnDataSource"},{"attributes":{"angle":{"units":"rad","value":1.570796325},"text_align":"center","text_color":{"value":"grey"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"397ad84e-c311-4f63-ba81-ae2a0cff728d","type":"Text"},{"attributes":{"callback":null,"column_names":["y","text","x"],"data":{"text":["DO std =  5.0 mg/L"],"x":[1.2735625],"y":[5]}},"id":"90d0381b-c62a-4373-9282-8056539ecae0","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"5e858a54-f4d6-4629-9c58-cb4f32cd1fa8","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["ELM FRK"],"x":[".00"],"y":[6.5]}},"id":"1cfeb350-227a-4f61-ba6e-b4c4842693af","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ea317efc-9266-466e-a5eb-f5f6bdfc5ef1","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8c28835f-5728-48bf-b572-4228f87c7cf7","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.29","2.29"],"y":[0.0,13.0]}},"id":"1c5a8e14-523a-48f4-9d97-7888f1928811","type":"ColumnDataSource"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"927652aa-c610-4fa4-a8a2-8c55eddf3fe5","type":"Line"},{"attributes":{"data_source":{"id":"559924a3-e1a0-4e71-8a47-c073f8fd3a4b","type":"ColumnDataSource"},"glyph":{"id":"22314389-8a64-48d4-bce8-91131cb0ba2d","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"ee4e224a-1f75-4ee5-a000-497ce83f3e77","type":"Text"},"selection_glyph":null},"id":"3c51aff4-e298-4921-8f27-2871621310c3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["KM 2.285"],"x":["2.29"],"y":[6.5]}},"id":"a3f8cf83-e7f4-45f8-8109-d326a50840ef","type":"ColumnDataSource"},{"attributes":{"text_color":{"value":"red"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2ee5d1a-59af-45b8-8624-90ffb63176f6","type":"Text"},{"attributes":{"data_source":{"id":"3c9d9873-77a7-47a5-9e2c-0e6ec817e1af","type":"ColumnDataSource"},"glyph":{"id":"c4e7edc5-b42e-400c-8a27-e41b1b12cf2e","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"74db4964-6b57-460a-a666-073d5a40fbb6","type":"Text"},"selection_glyph":null},"id":"a869a69c-37b1-4d52-8e22-11103f5f124b","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","text","x"],"data":{"text":["DO std =  4.8 mg/L"],"x":[0.0],"y":[4.8]}},"id":"19e67279- ...

# %%
print Points[i]
# Out:
# ELM FRK
