# %%
#Enter the location of the QUALTX output file
QUALTXoutfile = r'C:\Users\Ernest\Ernest_Sandbox\TurboQUALTX\TurboQUALTX\RB55NOV.OUT'

# %%
#Import python packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import os
import ET_Utils.QUALTX_Utils
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="dcb25065-5a31-441b-b167-5f75da1c0690">Loading BokehJS ...</span>
#     </div>

# %%
#Parse the QUALTX output file 
Scenario = QUALTXoutfile
DOstds = [5,4.8]
WQC_of_interest = ['DO_MG/L','BOD_MG/L','NH3_MG/L','NO3+2_MG/L','PHOS_MG/L']
StreamNames, Rdf, Hdf, AllWQdf = ET_Utils.QUALTX_Utils.Process_QUALTX(QUALTXoutfile,
                                                                      Scenario,DOstds = DOstds,
                                                                      WQC_of_interest = WQC_of_interest,
                                                                      loc = 1,plot_pdf = 0)
# Out:
# PECAN_LITTLE ELM CR
# OUTFALL 001 COVE
# OUTFALL 002 TRIB

# %%
#Perform plotting
x_range = [max(AllWQdf['ENDING_DIST']),min(AllWQdf['ENDING_DIST'])]

y_label = 'Concentration (mg/L)'
x_label = 'Distance (km)'

#Determine range of y-axis
maxy = []
for tempWQC in WQC_of_interest:
    maxy.append(max(AllWQdf[tempWQC]))
y_range = [0,round(max(maxy)*1.5)]

#Set line width
lws = np.zeros(len(WQC_of_interest))+2

#Set line colors
plot_colors = ['blue','black','green','cyan','orange']

#Set line symbols
plot_symbols = ['-','-','-','-','-']

#Set marker sizes
markersizes = np.zeros(len(WQC_of_interest))+1

#Set label sizes
x_labelsize = 15
y_labelsize = 15

# %%
# Loop through each stream and plot the WQ profile plot
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select"

#output_file("legend.html", title="legend.py example")

#show(vplot(p1, p2))  # open a browser

for StreamName in StreamNames:
    p = figure(title=StreamName, tools=TOOLS,x_range = x_range,y_range=y_range,plot_width=900, plot_height=450)  
    p.xaxis.axis_label = x_label
    p.yaxis.axis_label = y_label
    WQdf = AllWQdf[AllWQdf['Stream']==StreamName].copy()
    SRdf = Rdf[Rdf['StreamName']==StreamName].reset_index()
    
    for k in range(0,len(WQC_of_interest)):        
        #ls.append(ax.plot(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]),plot_symbols[k], 
        #lw = lws[k],markersize=markersizes[k],
        #                  color = plot_colors[k],label = WQC_of_interest[k]))
        # add a line renderer
        p.line(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]), 
               legend=WQC_of_interest[k], line_width= lws[k],
               color = plot_colors[k],name = WQC_of_interest[k])

         #Overplot reach start and end points of each reach
        if len(SRdf) > 0:
            Points1 = list(SRdf['BEGIN NAME'])
            Rkms1 = list(SRdf['BEGIN REACH KM'])
            if len(SRdf) > 1:
                Points2 = [SRdf['END NAME'][SRdf.index[-1]]]
                Rkms2 = [SRdf['END REACH KM'][SRdf.index[-1]]]
            else:
                Points2 = list(SRdf['END NAME'])
                Rkms2 = list(SRdf['END REACH KM'])
                
            Points = Points1 + Points2
        
            #Rkms = Rkms1.append(Rkms2)
            Rkms = Rkms1+Rkms2
        
            for i in range(0,len(Points)):
                #print Points[i]
                p.line([Rkms[i],Rkms[i]],y_range,'--',color = 'k')
                p.text(Rkms[i],np.mean(y_range),Points[i])#,text_align = 'center')#,angle = 3.14159265/2)
                

        if len(DOstds) > 0:
            for DOstd in DOstds:
                p.line(x_range,[DOstd,DOstd],'--',color = 'k')
                p.text(np.mean(x_range),DOstd,"DO std = "+"{:4.1f}".format(DOstd)+" mg/L")

        
    show(p)
# Out:
# FISH TRAP BRIDGE ABUTMNT
# COVE 1
# KM 2.285
# OUTFALL 002 INLET
# KM 1.885
# KM 1.735
# END OF MID-CHANNEL ISLE
# BEGINNING
# MIDDLE
# SOUTH END OF BEND
# WESTERN INLET
# HWY 380 BRIDGE
# FISH TRAP BRIDGE ABUTMNT
# COVE 1
# KM 2.285
# OUTFALL 002 INLET
# KM 1.885
# KM 1.735
# END OF MID-CHANNEL ISLE
# BEGINNING
# MIDDLE
# SOUTH END OF BEND
# WESTERN INLET
# HWY 380 BRIDGE
# FISH TRAP BRIDGE ABUTMNT
# COVE 1
# KM 2.285
# OUTFALL 002 INLET
# KM 1.885
# KM 1.735
# END OF MID-CHANNEL ISLE
# BEGINNING
# MIDDLE
# SOUTH END OF BEND
# WESTERN INLET
# HWY 380 BRIDGE
# FISH TRAP BRIDGE ABUTMNT
# COVE 1
# KM 2.285
# OUTFALL 002 INLET
# KM 1.885
# KM 1.735
# END OF MID-CHANNEL ISLE
# BEGINNING
# MIDDLE
# SOUTH END OF BEND
# WESTERN INLET
# HWY 380 BRIDGE
# FISH TRAP BRIDGE ABUTMNT
# COVE 1
# KM 2.285
# OUTFALL 002 INLET
# KM 1.885
# KM 1.735
# END OF MID-CHANNEL ISLE
# BEGINNING
# MIDDLE
# SOUTH END OF BEND
# WESTERN INLET
# HWY 380 BRIDGE
#     <div class="plotdiv" id="831311e7-9547-4db4-9cc3-3f1e223d5b4d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("831311e7-9547-4db4-9cc3-3f1e223d5b4d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '831311e7-9547-4db4-9cc3-3f1e223d5b4d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"68a15d7d-bb08-4930-8187-b8f5ffd73715":{"roots":{"references":[{"attributes":{"data_source":{"id":"05ef7983-74b7-4254-b695-3c1d0b4761dd","type":"ColumnDataSource"},"glyph":{"id":"a4bb507e-7b4d-4771-900d-a00dc856eb16","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"070d07ce-de11-4efe-ae88-af2ec1ff5dcd","type":"Line"},"selection_glyph":null},"id":"c591f361-8d35-484e-9814-b7970c603070","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"d979ef2c-a6d0-4fbb-8ec4-20354e1b015f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e4b2304f-85ff-4d3b-9c34-8d3401a22470","type":"ColumnDataSource"},"glyph":{"id":"2b2c10ca-58d7-4fb6-aec5-05be35c7ef95","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"e2f1fce8-c585-482f-8a24-d16a8fbd74a5","type":"Text"},"selection_glyph":null},"id":"29b84faf-a951-458d-af11-b5bfb758b17f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".00",".00"],"y":[0.0,13.0]}},"id":"bd9a09a4-7de7-4fa4-b71a-82de54c1af2b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2f692959-bd1e-44c4-a37b-8dff50c5977b","type":"ColumnDataSource"},"glyph":{"id":"fd0dc392-68ef-4bb1-b872-19b088917d8b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"90711ffa-cae6-40b9-9be8-ab15c1dc7b6d","type":"Line"},"selection_glyph":null},"id":"ecb5fd51-cade-4e7d-8fe1-badbf512ad96","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1f02bd05-df5d-44ee-aacc-d96af1836738","type":"ColumnDataSource"},"glyph":{"id":"e2adb794-0bd5-4958-a484-afc79fcc6680","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"918c43e6-8501-4882-933a-9a415be1abd5","type":"Line"},"selection_glyph":null},"id":"1c371647-33f2-494a-86fc-264cfca74356","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6f586b75-ad9e-4943-9e29-4ddac84061ee","type":"ColumnDataSource"},"glyph":{"id":"c036d2db-397f-40e6-8472-dfcd0792fbc7","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"d5ff8716-006f-449c-b335-744da395db80","type":"Text"},"selection_glyph":null},"id":"3b703ab0-27a5-4075-b223-c5c571193ae7","type":"GlyphRenderer"},{"attributes":{"text":{"field":"OUTFALL 002 INLET"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"2.04"},"y":{"value":6.5}},"id":"e6b68dfc-b752-4f33-b115-faf078ead1ce","type":"Text"},{"attributes":{"data_source":{"id":"81580a30-2215-43d8-85f8-a13d8f360d8e","type":"ColumnDataSource"},"glyph":{"id":"031c4bb2-794a-416a-8685-5f7e2444745f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ef67d382-456e-4036-8d7d-4136e15728c6","type":"Line"},"selection_glyph":null},"id":"13e81834-24f0-411d-8e1f-73ab76768d22","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.88","1.88"],"y":[0.0,13.0]}},"id":"9464e04f-d3e6-4cab-8533-f032fbff3c84","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9905fc76-91b2-4380-a5ad-1cda075c54d6","type":"ColumnDataSource"},"glyph":{"id":"35b4ae00-29ce-4166-ad21-a5f34cb95cb6","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"06908e8f-b6c8-453b-9bf6-113de47b62f4","type":"Text"},"selection_glyph":null},"id":"0922c63a-c4b5-4a01-b09a-7966d1165c1d","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":13.0},"id":"bf4ed87c-cacd-4365-aea7-4e0d4bc03e06","type":"Range1d"},{"attributes":{"data_source":{"id":"8351c8e6-33a4-4945-a8ff-2d616e093757","type":"ColumnDataSource"},"glyph":{"id":"411d2adb-9bfd-4944-b60c-9c5788c63881","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"323eb2c6-ccc6-432e-a6e3-4814b812709d","type":"Line"},"selection_glyph":null},"id":"3d6788dd-7a79-4646-b171-b7d1dfdc1cfc","type":"GlyphRenderer"},{"attributes":{},"id":"a68619df-77b0-491f-9257-819c3daa60e4","type":"BasicTickFormatter"},{"attributes":{"text":{"field":"BEGINNING"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"1.20"},"y":{"value":6.5}},"id":"c364af30-e38e-41fa-bc53 ...
# COVE 1: OUTFALL 001
# ELM FORK
# COVE 1: OUTFALL 001
# ELM FORK
# COVE 1: OUTFALL 001
# ELM FORK
# COVE 1: OUTFALL 001
# ELM FORK
# COVE 1: OUTFALL 001
# ELM FORK
#     <div class="plotdiv" id="ae436741-f0d4-4e6a-8f36-94bca19dfb56"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ae436741-f0d4-4e6a-8f36-94bca19dfb56");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ae436741-f0d4-4e6a-8f36-94bca19dfb56' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a22fc794-a5bb-4ff4-999b-1706f2e0a36d":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"319d9251-6e6b-4ed8-a3b5-a81387ac4226","type":"Line"},{"attributes":{"plot":{"id":"b2061127-318e-40c5-a399-bb1fa165eb50","subtype":"Figure","type":"Plot"}},"id":"a7a6b342-85f9-443c-b7d8-0e9807f6b43b","type":"ResetTool"},{"attributes":{"text":{"field":"DO std =  5.0 mg/L"},"text_color":{"value":"black"},"x":{"value":1.2425},"y":{"value":5}},"id":"d15a2585-c4f7-4e7e-8298-5463faec66ba","type":"Text"},{"attributes":{"callback":null},"id":"c56302c0-f1a4-4ad9-bf72-cf1cd2bcb1bc","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d979ef2c-a6d0-4fbb-8ec4-20354e1b015f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"e4b2304f-85ff-4d3b-9c34-8d3401a22470","type":"ColumnDataSource"},"glyph":{"id":"2b2c10ca-58d7-4fb6-aec5-05be35c7ef95","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"e2f1fce8-c585-482f-8a24-d16a8fbd74a5","type":"Text"},"selection_glyph":null},"id":"29b84faf-a951-458d-af11-b5bfb758b17f","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[".00",".00"],"y":[0.0,13.0]}},"id":"bd9a09a4-7de7-4fa4-b71a-82de54c1af2b","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2f692959-bd1e-44c4-a37b-8dff50c5977b","type":"ColumnDataSource"},"glyph":{"id":"fd0dc392-68ef-4bb1-b872-19b088917d8b","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"90711ffa-cae6-40b9-9be8-ab15c1dc7b6d","type":"Line"},"selection_glyph":null},"id":"ecb5fd51-cade-4e7d-8fe1-badbf512ad96","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"1f02bd05-df5d-44ee-aacc-d96af1836738","type":"ColumnDataSource"},"glyph":{"id":"e2adb794-0bd5-4958-a484-afc79fcc6680","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"918c43e6-8501-4882-933a-9a415be1abd5","type":"Line"},"selection_glyph":null},"id":"1c371647-33f2-494a-86fc-264cfca74356","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6f586b75-ad9e-4943-9e29-4ddac84061ee","type":"ColumnDataSource"},"glyph":{"id":"c036d2db-397f-40e6-8472-dfcd0792fbc7","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"d5ff8716-006f-449c-b335-744da395db80","type":"Text"},"selection_glyph":null},"id":"3b703ab0-27a5-4075-b223-c5c571193ae7","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"d889f2cc-65c1-446c-a212-23ad0f3d01e3","type":"Line"},{"attributes":{"text":{"field":"COVE 1: OUTFALL 001"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":".12"},"y":{"value":6.5}},"id":"49039739-d8f5-4642-bb3b-b5e2e69bdf22","type":"Text"},{"attributes":{"data_source":{"id":"05ef7983-74b7-4254-b695-3c1d0b4761dd","type":"ColumnDataSource"},"glyph":{"id":"a4bb507e-7b4d-4771-900d-a00dc856eb16","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"070d07ce-de11-4efe-ae88-af2ec1ff5dcd","type":"Line"},"selection_glyph":null},"id":"c591f361-8d35-484e-9814-b7970c603070","type":"GlyphRenderer"},{"attributes":{"text":{"field":"OUTFALL 002 INLET"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"2.04"},"y":{"value":6.5}},"id":"e6b68dfc-b752-4f33-b115-faf078ead1ce","type":"Text"},{"attributes":{"data_source":{"id":"81580a30-2215-43d8-85f8-a13d8f360d8e","type":"ColumnDataSource"},"glyph":{"id":"031c4bb2-794a-416a-8685-5f7e2444745f","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ef67d382-456e-4036-8d7d-4136e15728c6","type":"Line"},"selection_glyph":null},"id":"13e81834-24f0-411d-8e1f-73ab76768d22","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a689c52f-f2db-48af-bfab-c27e9ce0ec6b","type":"ColumnDataSource"},"glyph":{"id":"8d4519c2-9680-4a30-b1e0-0ddf0ef97607","type":"Line"},"hover_glyph":null,"name":"NO3+2_MG/L","nonselection_glyph":{" ...
# OUTFALL 002
# INUNDATED INLET START
# ELM FRK
