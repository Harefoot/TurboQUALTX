# %%
import pandas as pd
import os
pd.options.mode.chained_assignment = None  # default='warn'
import ET_Utils.QUALTX_Utils

# %%
inputfolder = r'C:\Users\Ernest\Ernest_Sandbox\TurboQUALTX\TurboQUALTX'
QUALTXoutfile = "RB55NOV.OUT"
Scenario = QUALTXoutfile
DOstds = [5,4.8]
WQC_of_interest = ['DO_MG/L','BOD_MG/L','NH3_MG/L','NO3+2_MG/L','PHOS_MG/L']
StreamNames, Rdf, Hdf, AllWQdf = ET_Utils.QUALTX_Utils.Process_QUALTX(inputfolder,QUALTXoutfile,
                                                                      Scenario,DOstds = DOstds,
                                                                      WQC_of_interest = WQC_of_interest,
                                                                      loc = 1,plot_pdf = 0)
# Out:
# PECAN_LITTLE ELM CR
# OUTFALL 001 COVE
# OUTFALL 002 TRIB

# %%
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e617d4c4-bbde-4c43-a930-b0e0f38b92bd">Loading BokehJS ...</span>
#     </div>

# %%
x_range = [min(AllWQdf['ENDING_DIST']),max(AllWQdf['ENDING_DIST'])]
y_label = 'mg/L'
x_label = 'km'
maxy = []
for tempWQC in WQC_of_interest:
    maxy.append(max(AllWQdf[tempWQC]))
y_range = [0,max(maxy)]

lws = np.zeros(len(WQC_of_interest))+2
plot_colors = ['blue','black','green','cyan','orange']
plot_symbols = ['-','-','-','-','-']
markersizes = np.zeros(len(WQC_of_interest))+1
x_labelsize = 15
y_labelsize = 15     
for StreamName in StreamNames:
    p = figure()
    p = figure(plot_width=900, plot_height=450)
    WQdf = AllWQdf[AllWQdf['Stream']==StreamName].copy()
    SRdf = Rdf[Rdf['StreamName']==StreamName].reset_index()
    
    for k in range(0,len(WQC_of_interest)):        
        #ls.append(ax.plot(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]),plot_symbols[k], 
        #lw = lws[k],markersize=markersizes[k],
        #                  color = plot_colors[k],label = WQC_of_interest[k]))
    # add a line renderer
        p.line(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]), line_width= lws[k],
                          color = plot_colors[k],name = WQC_of_interest[k])

    show(p)
# Out:
#     <div class="plotdiv" id="4754bbc2-76cc-46c8-8dac-ff72f976df4f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("4754bbc2-76cc-46c8-8dac-ff72f976df4f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '4754bbc2-76cc-46c8-8dac-ff72f976df4f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"697b11cf-d753-4d75-9ef1-4b1ffadc2bea":{"roots":{"references":[{"attributes":{"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"3dc64fb7-607d-4f3b-ab71-0a71e3151822","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"5bd795d8-457b-4c85-bc03-f32a4c2255e1","type":"Line"},{"attributes":{},"id":"e744390d-1f98-4855-82e8-302d90c22547","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.485,2.385,2.285,2.16,2.035,1.885,1.735,1.615,1.495,1.375,1.2,1.03,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1,0.0],"y":[6.61,6.54,6.67,6.77,6.84,6.64,6.72,6.77,6.86,7.04,7.37,7.76,8.09,8.29,8.44,8.58,8.71,8.83,8.92,8.93,8.82,8.51]}},"id":"e81acd31-248a-45ce-9ffe-22d7fec45bc1","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"8c8aeb05-e5be-476f-8ab7-5cee9ed59c0d","type":"ResetTool"},{"attributes":{"line_color":{"value":"blue"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"f40f0ef4-c0ce-490f-8a9a-bdd67b14aea3","type":"Line"},{"attributes":{"data_source":{"id":"42f80b16-7149-49e3-ba0b-7ee7a3ea4e26","type":"ColumnDataSource"},"glyph":{"id":"ae63eda5-11b5-4876-a875-41281226548c","type":"Line"},"hover_glyph":null,"name":"BOD_MG/L","nonselection_glyph":{"id":"4bdd5de4-0826-4d8c-9e4e-8326a76c7647","type":"Line"},"selection_glyph":null},"id":"6d46251f-1bcb-4b4c-abe7-9a4482667aec","type":"GlyphRenderer"},{"attributes":{},"id":"a7382062-0d87-4337-9196-1f97313ba0b6","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"},"ticker":{"id":"711cf65f-9333-4980-a4fc-aa8e5913c01a","type":"BasicTicker"}},"id":"6208d1b7-6ab8-40f2-a374-2dda7b66d772","type":"Grid"},{"attributes":{"line_color":{"value":"cyan"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"c763bed0-fc30-48d2-928a-71f92289933d","type":"Line"},{"attributes":{"overlay":{"id":"a4432227-65b5-4402-b593-2aa33484bfd9","type":"BoxAnnotation"},"plot":{"id":"528a6c4c-b7af-4598-b9b9-f5de835dd161","subtype":"Figure","type":"Plot"}},"id":"f485695d-68e0-49a8-89f3-d0eb664e46e6","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"1857e5e9-8028-45d1-a44d-5ce9b540de99","type":"Line"},{"attributes":{"plot":{"id":"528a6c4c-b7af-4598-b9b9-f5de835dd161","subtype":"Figure","type":"Plot"}},"id":"be652e83-25e6-443f-b6a2-91fd98d36e23","type":"ResizeTool"},{"attributes":{"data_source":{"id":"a4315277-1680-48db-b059-ba4666653f5b","type":"ColumnDataSource"},"glyph":{"id":"001037af-027d-4f2a-a4f8-e69aa4aa47c0","type":"Line"},"hover_glyph":null,"name":"PHOS_MG/L","nonselection_glyph":{"id":"e4af58dd-7c80-495d-8db0-aef5c4f56191","type":"Line"},"selection_glyph":null},"id":"e2b5667d-2d7d-451a-aa70-abf5a87bebc6","type":"GlyphRenderer"},{"attributes":{},"id":"43f099fd-aacf-475c-bb38-6e5d4d9dcf36","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"570a8504-4a77-4cf4-8295-71b138db89da","type":"BoxAnnotation"},"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"e4fdcf38-1c03-40db-9164-1e3c60b6d034","type":"BoxZoomTool"},{"attributes":{},"id":"64beb70c-0fbc-4e9d-bd7c-2d03a4532267","type":"BasicTicker"},{"attributes":{"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"f2139280-4a83-4a5e-b5ae-165951a8d0d3","type":"HelpTool"},{"attributes":{"data_source":{"id":"5fee3258-2377-4dd1-8106-27ff2ebef3da","type":"ColumnDataSource"},"glyph":{"id":"30ac909c-508a-45de-b057-7e40cc47548d","type":"Line"},"hover_glyph":null,"name":"NH3_MG/L","nonselection_glyph":{"id":"c9ee425d-c675-4b05-a775-f2dd9db1d543","type":"Line"},"selection_g ...
#     <div class="plotdiv" id="c60768a0-e026-4793-b5cb-5b1727f438c7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c60768a0-e026-4793-b5cb-5b1727f438c7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c60768a0-e026-4793-b5cb-5b1727f438c7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5697f005-512d-47a4-a2e0-d1aa9ad63767":{"roots":{"references":[{"attributes":{"callback":null},"id":"1c9347ed-0156-4134-9090-57012683c9a3","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.485,2.385,2.285,2.16,2.035,1.885,1.735,1.615,1.495,1.375,1.2,1.03,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1,0.0],"y":[6.61,6.54,6.67,6.77,6.84,6.64,6.72,6.77,6.86,7.04,7.37,7.76,8.09,8.29,8.44,8.58,8.71,8.83,8.92,8.93,8.82,8.51]}},"id":"e81acd31-248a-45ce-9ffe-22d7fec45bc1","type":"ColumnDataSource"},{"attributes":{"dimension":1,"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"},"ticker":{"id":"711cf65f-9333-4980-a4fc-aa8e5913c01a","type":"BasicTicker"}},"id":"6208d1b7-6ab8-40f2-a374-2dda7b66d772","type":"Grid"},{"attributes":{"plot":{"id":"2b8951b9-18e0-4a9a-8343-64052652efc5","subtype":"Figure","type":"Plot"}},"id":"22efe24d-a3b8-4787-bb6c-1834d99dcb77","type":"ResetTool"},{"attributes":{},"id":"c5bbb04a-bc60-4ad4-b815-1cd0e7a2c3b6","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"570a8504-4a77-4cf4-8295-71b138db89da","type":"BoxAnnotation"},"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"e4fdcf38-1c03-40db-9164-1e3c60b6d034","type":"BoxZoomTool"},{"attributes":{},"id":"64beb70c-0fbc-4e9d-bd7c-2d03a4532267","type":"BasicTicker"},{"attributes":{},"id":"7c7cb21e-707f-47a1-910f-d5d37631f0b3","type":"BasicTicker"},{"attributes":{"line_color":{"value":"cyan"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"c763bed0-fc30-48d2-928a-71f92289933d","type":"Line"},{"attributes":{"line_color":{"value":"orange"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"75ddbb43-c895-4e34-ae16-275ac40d6f5d","type":"Line"},{"attributes":{"formatter":{"id":"c5bbb04a-bc60-4ad4-b815-1cd0e7a2c3b6","type":"BasicTickFormatter"},"plot":{"id":"3ab27eec-cbfb-4a98-a1a3-c47a1cbd43a6","subtype":"Figure","type":"Plot"},"ticker":{"id":"ddd8a6bd-73c5-402f-8a2a-e944a429a196","type":"BasicTicker"}},"id":"17e045d7-adf7-4676-b510-ef40a02b2bb0","type":"LinearAxis"},{"attributes":{"callback":null},"id":"80e18b45-c342-4871-97d3-d1b04848de7b","type":"DataRange1d"},{"attributes":{"plot":{"id":"2b8951b9-18e0-4a9a-8343-64052652efc5","subtype":"Figure","type":"Plot"},"ticker":{"id":"1566b8bf-9d3e-434c-81f2-bc7dc2832bce","type":"BasicTicker"}},"id":"c6d7901a-6761-4c58-ae30-57d03b7dc1a4","type":"Grid"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0],"y":[4.86]}},"id":"bff53dd9-efa7-4ff1-8cfa-1a080b550972","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"3ab27eec-cbfb-4a98-a1a3-c47a1cbd43a6","subtype":"Figure","type":"Plot"},"ticker":{"id":"b9ec3494-1d1c-493e-9806-ecf6dfc47c9c","type":"BasicTicker"}},"id":"3ee1c48f-35c9-40f4-9650-3402b7e2e342","type":"Grid"},{"attributes":{"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"95a9f265-6266-4250-bc66-ea4d3e74eeb4","type":"PreviewSaveTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"c9ee425d-c675-4b05-a775-f2dd9db1d543","type":"Line"},{"attributes":{"data_source":{"id":"e81acd31-248a-45ce-9ffe-22d7fec45bc1","type":"ColumnDataSource"},"glyph":{"id":"f40f0ef4-c0ce-490f-8a9a-bdd67b14aea3","type":"Line"},"hover_glyph":null,"name":"DO_MG/L","nonselection_glyph":{"id":"1857e5e9-8028-45d1-a44d-5ce9b540de99","type":"Line"},"selection_glyph":null},"id":"25319886-c04b-424c-a1e2-239cac8348a0","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"43f099fd-aacf-475c-bb38-6e5d4d9dcf36","type":"BasicTickFormatter"},"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"},"ticker":{"id":"3fe19c82-9051-4802-9832-17bc639ec64c","type":"BasicTicker"}},"id":"9b7e4700-f70c-4510-ab32-9c865bfdb4c5","type":"LinearAxis"},{"attributes":{"overlay":{"id":"67e33df0-3071-4db ...
#     <div class="plotdiv" id="41bae674-94ce-493b-bc6e-1acadeaf2a62"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("41bae674-94ce-493b-bc6e-1acadeaf2a62");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '41bae674-94ce-493b-bc6e-1acadeaf2a62' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5aa477a9-5db5-4bc3-a1d7-0bce62fe48f6":{"roots":{"references":[{"attributes":{"callback":null},"id":"1c9347ed-0156-4134-9090-57012683c9a3","type":"DataRange1d"},{"attributes":{"callback":null},"id":"75af1d15-58ea-4c9c-9b1b-40b3e3e29220","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.485,2.385,2.285,2.16,2.035,1.885,1.735,1.615,1.495,1.375,1.2,1.03,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1,0.0],"y":[6.61,6.54,6.67,6.77,6.84,6.64,6.72,6.77,6.86,7.04,7.37,7.76,8.09,8.29,8.44,8.58,8.71,8.83,8.92,8.93,8.82,8.51]}},"id":"e81acd31-248a-45ce-9ffe-22d7fec45bc1","type":"ColumnDataSource"},{"attributes":{},"id":"756d9f3c-31a3-4d80-821a-f1e11f50d8e6","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"},"ticker":{"id":"711cf65f-9333-4980-a4fc-aa8e5913c01a","type":"BasicTicker"}},"id":"6208d1b7-6ab8-40f2-a374-2dda7b66d772","type":"Grid"},{"attributes":{"plot":{"id":"528a6c4c-b7af-4598-b9b9-f5de835dd161","subtype":"Figure","type":"Plot"},"ticker":{"id":"64beb70c-0fbc-4e9d-bd7c-2d03a4532267","type":"BasicTicker"}},"id":"5b8a7aa6-c56b-4208-9e04-3014ba04c1a6","type":"Grid"},{"attributes":{"plot":{"id":"2b8951b9-18e0-4a9a-8343-64052652efc5","subtype":"Figure","type":"Plot"}},"id":"22efe24d-a3b8-4787-bb6c-1834d99dcb77","type":"ResetTool"},{"attributes":{"formatter":{"id":"f8279e6d-d9b8-4225-ad0e-00ef93871214","type":"BasicTickFormatter"},"plot":{"id":"ba271dbc-b3e5-4112-b54d-eb3f59c89b07","subtype":"Figure","type":"Plot"},"ticker":{"id":"da483400-0e1d-43bc-ae08-eb14616dfb70","type":"BasicTicker"}},"id":"19e671e1-0892-4ca5-991b-f22bd97446f5","type":"LinearAxis"},{"attributes":{},"id":"e744390d-1f98-4855-82e8-302d90c22547","type":"BasicTicker"},{"attributes":{},"id":"c5bbb04a-bc60-4ad4-b815-1cd0e7a2c3b6","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"570a8504-4a77-4cf4-8295-71b138db89da","type":"BoxAnnotation"},"plot":{"id":"b39115f2-dcf6-43d1-a1b9-1d1ad5839931","subtype":"Figure","type":"Plot"}},"id":"e4fdcf38-1c03-40db-9164-1e3c60b6d034","type":"BoxZoomTool"},{"attributes":{},"id":"64beb70c-0fbc-4e9d-bd7c-2d03a4532267","type":"BasicTicker"},{"attributes":{},"id":"7c7cb21e-707f-47a1-910f-d5d37631f0b3","type":"BasicTicker"},{"attributes":{"data_source":{"id":"fbc61cd0-2e1a-43f9-8b27-d822594feaa9","type":"ColumnDataSource"},"glyph":{"id":"7635892e-2246-4e47-aa6b-5cb228d84079","type":"Line"},"hover_glyph":null,"name":"PHOS_MG/L","nonselection_glyph":{"id":"3ddbba60-d63b-401d-8fdc-31ee0a0f8834","type":"Line"},"selection_glyph":null},"id":"e70c0d26-8ad6-41d3-800f-86e6f464e01f","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"cyan"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"c763bed0-fc30-48d2-928a-71f92289933d","type":"Line"},{"attributes":{"data_source":{"id":"de8a46ab-0ea6-4204-ae9e-134268c09a14","type":"ColumnDataSource"},"glyph":{"id":"5b267736-17df-4bd6-b642-f9376e9891a1","type":"Line"},"hover_glyph":null,"name":"NO3+2_MG/L","nonselection_glyph":{"id":"c51e2120-9ff0-4273-a245-2b1177bd1de6","type":"Line"},"selection_glyph":null},"id":"d0bc5a62-d546-45ba-87cd-160f817a66ee","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"c5bbb04a-bc60-4ad4-b815-1cd0e7a2c3b6","type":"BasicTickFormatter"},"plot":{"id":"3ab27eec-cbfb-4a98-a1a3-c47a1cbd43a6","subtype":"Figure","type":"Plot"},"ticker":{"id":"ddd8a6bd-73c5-402f-8a2a-e944a429a196","type":"BasicTicker"}},"id":"17e045d7-adf7-4676-b510-ef40a02b2bb0","type":"LinearAxis"},{"attributes":{"data_source":{"id":"9e8dea3d-62fe-4c9a-b687-61ab89fe4333","type":"ColumnDataSource"},"glyph":{"id":"b319f3e8-c478-4e29-9095-0f26638105c7","type":"Line"},"hover_glyph":null,"name":"NH3_MG/L","nonselection_glyph":{"id":"7c6f10b3-4d2e-472b-8bef-4e5408908ba3","type":"Line"},"selection_glyph":null},"id":"3bb28e58-6212-43ee-afac-9f32bf974c32","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"blue"},"line_width" ...
