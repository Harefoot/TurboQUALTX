# %%
#Enter the location of the QUALTX output file
QUALTXoutfile = r'C:\Users\Ernest\Ernest_Sandbox\TurboQUALTX\TurboQUALTX\RB55NOV.OUT'

# %%
#Import python packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import os
import ET_Utils.QUALTX_Utils
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2667cf23-9bfe-4a95-8e2d-53ded5ca0e11">Loading BokehJS ...</span>
#     </div>

# %%
#Parse the QUALTX output file 
Scenario = QUALTXoutfile
DOstds = [5,4.8]
WQC_of_interest = ['DO_MG/L','BOD_MG/L','NH3_MG/L','NO3+2_MG/L','PHOS_MG/L']
StreamNames, Rdf, Hdf, AllWQdf = ET_Utils.QUALTX_Utils.Process_QUALTX(QUALTXoutfile,
                                                                      Scenario,DOstds = DOstds,
                                                                      WQC_of_interest = WQC_of_interest,
                                                                      loc = 1,plot_pdf = 0)
# Out:
# PECAN_LITTLE ELM CR
# OUTFALL 001 COVE
# OUTFALL 002 TRIB

# %%
#Perform plotting
y_label = 'Concentration (mg/L)'
x_label = 'Distance (km)'

#Determine range of y-axis
maxy = []
for tempWQC in WQC_of_interest:
    maxy.append(max(AllWQdf[tempWQC]))
y_range = [0,round(max(maxy)*1.5)]

#Set line width
lws = np.zeros(len(WQC_of_interest))+2

#Set line colors
plot_colors = ['blue','black','green','cyan','orange']

#Set line symbols
plot_symbols = ['-','-','-','-','-']

#Set marker sizes
markersizes = np.zeros(len(WQC_of_interest))+1

#Set label sizes
x_labelsize = 15
y_labelsize = 15

# %%
# Loop through each stream and plot the WQ profile plot
#TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select"
#TOOLS = [BoxSelectTool(), HoverTool()]
TOOLS="hover"
    
#output_file("legend.html", title="legend.py example")

#show(vplot(p1, p2))  # open a browser

for StreamName in StreamNames:
    WQdf = AllWQdf[AllWQdf['Stream']==StreamName].copy()
    SRdf = Rdf[Rdf['StreamName']==StreamName].reset_index()
    x_range = [max(WQdf['ENDING_DIST'])*1.025,min(WQdf['ENDING_DIST'])]
    p = figure(title=StreamName, tools=TOOLS,x_range = x_range,y_range=y_range,plot_width=900, plot_height=450)  
    if StreamName == StreamNames[0]:
        hover = p.select(dict(type=HoverTool))
        hover.tooltips = [
            # add to this
            ("Conc ", "$y mg/L"),
        ]    
    p.xaxis.axis_label = x_label
    p.yaxis.axis_label = y_label

    
    for k in range(0,len(WQC_of_interest)):        
        #ls.append(ax.plot(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]),plot_symbols[k], 
        #lw = lws[k],markersize=markersizes[k],
        #                  color = plot_colors[k],label = WQC_of_interest[k]))
        # add a line renderer
        p.line(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]), 
               legend=WQC_of_interest[k], line_width= lws[k],
               color = plot_colors[k],name = WQC_of_interest[k])

         #Overplot reach start and end points of each reach
        if len(SRdf) > 0:
            Points1 = list(SRdf['BEGIN NAME'])
            Rkms1 = list(SRdf['BEGIN REACH KM'])
            if len(SRdf) > 1:
                Points2 = [SRdf['END NAME'][SRdf.index[-1]]]
                Rkms2 = [SRdf['END REACH KM'][SRdf.index[-1]]]
            else:
                Points2 = list(SRdf['END NAME'])
                Rkms2 = list(SRdf['END REACH KM'])
                
            Points = Points1 + Points2
        
            #Rkms = Rkms1.append(Rkms2)
            Rkms = Rkms1+Rkms2
        #p1.text([65,65,65],[65,65,65], text=[ str(i) for i in x], alpha=0.5, text_font_size="5pt", text_baseline="middle", 
        #text_align="center")
            for i in range(0,len(Points)):
                #print Points[i]
                p.line([Rkms[i],Rkms[i]],y_range,'..',color = 'grey')
                p.text([Rkms[i]],[np.mean(y_range)],text = [Points[i]],text_align = 'center',
                       angle = 3.14159265/2,text_font_size = '9pt',text_color = 'grey')
                
        
        if len(DOstds) > 0:
            for DOstd in DOstds:
                p.line(x_range,[DOstd,DOstd],'..',color = 'red')
                #print DOstd
                p.text([np.mean(x_range)],[DOstd],text = ["DO std = "+"{:4.1f}".format(DOstd)+" mg/L"],
                       text_font_size = '9pt',text_color = 'red')
                #p.text(np.mean(x_range),DOstd,"DO std = Monkey mg/L")

        p.xgrid.grid_line_color = None
        p.ygrid.grid_line_color = None
    show(p)
# Out:
#     <div class="plotdiv" id="0bb54758-3342-4ffd-928f-fe2a23e0e9ce"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0bb54758-3342-4ffd-928f-fe2a23e0e9ce");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0bb54758-3342-4ffd-928f-fe2a23e0e9ce' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cdf41e17-6d2c-4aa4-a75d-522a5fbf9892":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd831829-c231-4716-ac79-1cb6e3cfaf32","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.03","1.03"],"y":[0.0,13.0]}},"id":"78b76a77-5433-4e53-a9d8-feb289ee505e","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c835d9f5-e11a-473e-b772-ba2abe046e29","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba85a61e-b022-4060-a294-303f6adfe914","type":"Line"},{"attributes":{"angle":{"units":"rad","value":1.570796325},"text_align":"center","text_color":{"value":"grey"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e1a3a357-83c4-4cd2-bacf-a0de243ea45b","type":"Text"},{"attributes":{"data_source":{"id":"a9d1876f-24c6-4b43-861a-f16bfe4fc114","type":"ColumnDataSource"},"glyph":{"id":"24b37609-5906-4f2e-9feb-e8ea2102d607","type":"Line"},"hover_glyph":null,"name":"NO3+2_MG/L","nonselection_glyph":{"id":"65c76de9-d260-431d-89b1-e67d0911dbdc","type":"Line"},"selection_glyph":null},"id":"cdddfd40-b052-4464-a4da-3bf856bf322b","type":"GlyphRenderer"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fcab38bd-f0eb-4d12-8fdf-7cac92af1a60","type":"Text"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.547125,0.0],"y":[4.8,4.8]}},"id":"468d3b6c-e973-4014-9aea-0ac339f096ea","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cd3ef489-cb30-481b-890c-06764c71f6e5","type":"ColumnDataSource"},"glyph":{"id":"6e4161a3-e619-4583-b030-18e4d7debe94","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f0f9eb80-70c8-4f7c-b4f7-e1b6e1c6ebb9","type":"Line"},"selection_glyph":null},"id":"7e0815c4-0d4a-4b25-9b70-f762f3506a56","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["INUNDATED INLET START"],"x":[".15"],"y":[6.5]}},"id":"89a7f4e9-0e12-4986-9ca9-1fcbcb1706e4","type":"ColumnDataSource"},{"attributes":{},"id":"53737dbc-7203-4c72-9053-5605674e9efa","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.29","2.29"],"y":[0.0,13.0]}},"id":"c880a168-774a-4a5d-85d9-9c352c771790","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61296876-328e-4dea-b4c3-582f2f24c683","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.20","1.20"],"y":[0.0,13.0]}},"id":"45665f21-2888-4b29-aa1b-3c32c4816311","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8a6e3dcb-8d39-416e-bd06-e1bacfef4f28","type":"ColumnDataSource"},"glyph":{"id":"a2c5f239-e50a-4b8d-b10b-98aac7c39242","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ecc458cd-f4ef-4491-865d-40bd08e5b4a1","type":"Line"},"selection_glyph":null},"id":"ef397fe9-8da6-4271-90c9-66ba9dfac51f","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"d4996947-59c6-4a6a-ab39-b4744f5e0ab5","type":"ColumnDataSource"},"glyph":{"id":"fd23cd71-b0cd-4c5d-9f7e-e041096c71bc","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"3f4a031d-c232-4a60-acc5-f631bcd88817","type":"Text"},"selection_glyph":null},"id":"b2b520bd-8f6c-4b41-9e3f-ef2e61a54c12","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"91ed539a-adbe-4c0f-8abc-2ec15e24f7ff","type":"Line"},{"attributes":{"data_source":{"id":"f500396d-2293-44d1-90fd-791cd7884a71","type":"ColumnDataSource"},"glyph":{"id":"2ec64705-1228-4484-a0b9-04dcfa5aaa9a","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"f39e5626-9006-45c ...
#     <div class="plotdiv" id="aa09bc10-640e-48b5-a71e-07aeacaac55d"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aa09bc10-640e-48b5-a71e-07aeacaac55d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aa09bc10-640e-48b5-a71e-07aeacaac55d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"2f924078-a0f0-4020-a8b0-29a020c9e6c4":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd831829-c231-4716-ac79-1cb6e3cfaf32","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.03","1.03"],"y":[0.0,13.0]}},"id":"78b76a77-5433-4e53-a9d8-feb289ee505e","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c835d9f5-e11a-473e-b772-ba2abe046e29","type":"Line"},{"attributes":{"data_source":{"id":"589b37c0-ce8d-415a-abe8-918836c9ca2b","type":"ColumnDataSource"},"glyph":{"id":"b65cf438-8732-4755-992d-bad0a14c220e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"09aad299-8a1b-437f-93d7-84a22d3ecc00","type":"Line"},"selection_glyph":null},"id":"d4f3d71e-db48-4e9f-81f6-aa564a6e7559","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba85a61e-b022-4060-a294-303f6adfe914","type":"Line"},{"attributes":{"data_source":{"id":"3445fcf1-d54a-4832-baea-ef2e720d80cf","type":"ColumnDataSource"},"glyph":{"id":"e5478b3d-5142-4444-9983-0214260c4897","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"fb062931-6cac-44ec-9033-c7e19acc9c9d","type":"Text"},"selection_glyph":null},"id":"a2caec1b-9379-477e-bd13-1a4ec13bf4ff","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"a9d1876f-24c6-4b43-861a-f16bfe4fc114","type":"ColumnDataSource"},"glyph":{"id":"24b37609-5906-4f2e-9feb-e8ea2102d607","type":"Line"},"hover_glyph":null,"name":"NO3+2_MG/L","nonselection_glyph":{"id":"65c76de9-d260-431d-89b1-e67d0911dbdc","type":"Line"},"selection_glyph":null},"id":"cdddfd40-b052-4464-a4da-3bf856bf322b","type":"GlyphRenderer"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fcab38bd-f0eb-4d12-8fdf-7cac92af1a60","type":"Text"},{"attributes":{"data_source":{"id":"d283fa8c-c4a2-43de-a125-f0cf27c3d7b9","type":"ColumnDataSource"},"glyph":{"id":"45cde87b-d3b3-4852-91fe-f27e158ac449","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"05721e37-6611-4dea-b549-db01bc890539","type":"Text"},"selection_glyph":null},"id":"5e5d0fd2-0957-4719-b856-485af7ce8b53","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.547125,0.0],"y":[4.8,4.8]}},"id":"468d3b6c-e973-4014-9aea-0ac339f096ea","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cd3ef489-cb30-481b-890c-06764c71f6e5","type":"ColumnDataSource"},"glyph":{"id":"6e4161a3-e619-4583-b030-18e4d7debe94","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f0f9eb80-70c8-4f7c-b4f7-e1b6e1c6ebb9","type":"Line"},"selection_glyph":null},"id":"7e0815c4-0d4a-4b25-9b70-f762f3506a56","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["INUNDATED INLET START"],"x":[".15"],"y":[6.5]}},"id":"89a7f4e9-0e12-4986-9ca9-1fcbcb1706e4","type":"ColumnDataSource"},{"attributes":{},"id":"53737dbc-7203-4c72-9053-5605674e9efa","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.29","2.29"],"y":[0.0,13.0]}},"id":"c880a168-774a-4a5d-85d9-9c352c771790","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["SOUTH END OF BEND"],"x":[".90"],"y":[6.5]}},"id":"166cbba4-9a33-45c5-8f8b-32051da11582","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61296876-328e-4dea-b4c3-582f2f24c683","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.20","1.20"],"y":[0.0,13.0]}},"id":"45665f21-2888-4b29-aa1b-3c32c4816311","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8a6e3dcb-8d39-416e-bd06-e1bacfef4f28","type":"Column ...
#     <div class="plotdiv" id="53e19b89-c6fa-4ced-8ac5-481f32c0ce08"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("53e19b89-c6fa-4ced-8ac5-481f32c0ce08");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '53e19b89-c6fa-4ced-8ac5-481f32c0ce08' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"379fe374-71b8-439c-80a0-84bc6fe2db91":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dd831829-c231-4716-ac79-1cb6e3cfaf32","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.03","1.03"],"y":[0.0,13.0]}},"id":"78b76a77-5433-4e53-a9d8-feb289ee505e","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"grey"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c835d9f5-e11a-473e-b772-ba2abe046e29","type":"Line"},{"attributes":{"data_source":{"id":"589b37c0-ce8d-415a-abe8-918836c9ca2b","type":"ColumnDataSource"},"glyph":{"id":"b65cf438-8732-4755-992d-bad0a14c220e","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"09aad299-8a1b-437f-93d7-84a22d3ecc00","type":"Line"},"selection_glyph":null},"id":"d4f3d71e-db48-4e9f-81f6-aa564a6e7559","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba85a61e-b022-4060-a294-303f6adfe914","type":"Line"},{"attributes":{"angle":{"units":"rad","value":1.570796325},"text_align":"center","text_color":{"value":"grey"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e1a3a357-83c4-4cd2-bacf-a0de243ea45b","type":"Text"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1975c9c1-5dd0-4ba7-83e4-4830778c31f5","type":"Line"},{"attributes":{"data_source":{"id":"a9d1876f-24c6-4b43-861a-f16bfe4fc114","type":"ColumnDataSource"},"glyph":{"id":"24b37609-5906-4f2e-9feb-e8ea2102d607","type":"Line"},"hover_glyph":null,"name":"NO3+2_MG/L","nonselection_glyph":{"id":"65c76de9-d260-431d-89b1-e67d0911dbdc","type":"Line"},"selection_glyph":null},"id":"cdddfd40-b052-4464-a4da-3bf856bf322b","type":"GlyphRenderer"},{"attributes":{"text_alpha":{"value":0.1},"text_color":{"value":"black"},"text_font_size":{"value":"9pt"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fcab38bd-f0eb-4d12-8fdf-7cac92af1a60","type":"Text"},{"attributes":{"data_source":{"id":"d283fa8c-c4a2-43de-a125-f0cf27c3d7b9","type":"ColumnDataSource"},"glyph":{"id":"45cde87b-d3b3-4852-91fe-f27e158ac449","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"05721e37-6611-4dea-b549-db01bc890539","type":"Text"},"selection_glyph":null},"id":"5e5d0fd2-0957-4719-b856-485af7ce8b53","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[2.547125,0.0],"y":[4.8,4.8]}},"id":"468d3b6c-e973-4014-9aea-0ac339f096ea","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cd3ef489-cb30-481b-890c-06764c71f6e5","type":"ColumnDataSource"},"glyph":{"id":"6e4161a3-e619-4583-b030-18e4d7debe94","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"f0f9eb80-70c8-4f7c-b4f7-e1b6e1c6ebb9","type":"Line"},"selection_glyph":null},"id":"7e0815c4-0d4a-4b25-9b70-f762f3506a56","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","text"],"data":{"text":["INUNDATED INLET START"],"x":[".15"],"y":[6.5]}},"id":"89a7f4e9-0e12-4986-9ca9-1fcbcb1706e4","type":"ColumnDataSource"},{"attributes":{},"id":"53737dbc-7203-4c72-9053-5605674e9efa","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["2.29","2.29"],"y":[0.0,13.0]}},"id":"c880a168-774a-4a5d-85d9-9c352c771790","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"red"},"x":{"field":"x"},"y":{"field":"y"}},"id":"61296876-328e-4dea-b4c3-582f2f24c683","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.20","1.20"],"y":[0.0,13.0]}},"id":"45665f21-2888-4b29-aa1b-3c32c4816311","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"8a6e3dcb-8d39-416e-bd06-e1bacfef4f28","type":"ColumnDataSource"},"glyph":{"id":"a2c5f239-e50a-4b8d-b10b-98aac7c39242","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ecc458cd-f4ef-449 ...
