# %%
#Enter the location of the QUALTX output file
QUALTXoutfile = r'C:\Users\Ernest\Ernest_Sandbox\TurboQUALTX\TurboQUALTX\RB55NOV.OUT'

# %%
#Import python packages
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'
import os
import ET_Utils.QUALTX_Utils
import numpy as np
import bokeh
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c35ebb0d-f81e-40ec-bf0e-b76e26e6e6e4">Loading BokehJS ...</span>
#     </div>

# %%
#Parse the QUALTX output file 
Scenario = QUALTXoutfile
DOstds = [5,4.8]
WQC_of_interest = ['DO_MG/L','BOD_MG/L','NH3_MG/L','NO3+2_MG/L','PHOS_MG/L']
StreamNames, Rdf, Hdf, AllWQdf = ET_Utils.QUALTX_Utils.Process_QUALTX(QUALTXoutfile,
                                                                      Scenario,DOstds = DOstds,
                                                                      WQC_of_interest = WQC_of_interest,
                                                                      loc = 1,plot_pdf = 0)
# Out:
# PECAN_LITTLE ELM CR
# OUTFALL 001 COVE
# OUTFALL 002 TRIB

# %%
#Perform plotting
x_range = [max(AllWQdf['ENDING_DIST']),min(AllWQdf['ENDING_DIST'])]

y_label = 'Concentration (mg/L)'
x_label = 'Distance (km)'

#Determine range of y-axis
maxy = []
for tempWQC in WQC_of_interest:
    maxy.append(max(AllWQdf[tempWQC]))
y_range = [0,round(max(maxy)*1.5)]

#Set line width
lws = np.zeros(len(WQC_of_interest))+2

#Set line colors
plot_colors = ['blue','black','green','cyan','orange']

#Set line symbols
plot_symbols = ['-','-','-','-','-']

#Set marker sizes
markersizes = np.zeros(len(WQC_of_interest))+1

#Set label sizes
x_labelsize = 15
y_labelsize = 15

# %%
# Loop through each stream and plot the WQ profile plot
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select"

#output_file("legend.html", title="legend.py example")

#show(vplot(p1, p2))  # open a browser

for StreamName in StreamNames:
    p = figure(title=StreamName, tools=TOOLS,x_range = x_range,y_range=y_range,plot_width=900, plot_height=450)  
    p.xaxis.axis_label = x_label
    p.yaxis.axis_label = y_label
    WQdf = AllWQdf[AllWQdf['Stream']==StreamName].copy()
    SRdf = Rdf[Rdf['StreamName']==StreamName].reset_index()
    
    for k in range(0,len(WQC_of_interest)):        
        #ls.append(ax.plot(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]),plot_symbols[k], 
        #lw = lws[k],markersize=markersizes[k],
        #                  color = plot_colors[k],label = WQC_of_interest[k]))
        # add a line renderer
        p.line(np.asarray(WQdf['ENDING_DIST']),np.asarray(WQdf[WQC_of_interest[k]]), 
               legend=WQC_of_interest[k], line_width= lws[k],
               color = plot_colors[k],name = WQC_of_interest[k])

         #Overplot reach start and end points of each reach
        if len(SRdf) > 0:
            Points1 = list(SRdf['BEGIN NAME'])
            Rkms1 = list(SRdf['BEGIN REACH KM'])
            if len(SRdf) > 1:
                Points2 = [SRdf['END NAME'][SRdf.index[-1]]]
                Rkms2 = [SRdf['END REACH KM'][SRdf.index[-1]]]
            else:
                Points2 = list(SRdf['END NAME'])
                Rkms2 = list(SRdf['END REACH KM'])
                
            Points = Points1 + Points2
        
            #Rkms = Rkms1.append(Rkms2)
            Rkms = Rkms1+Rkms2
        
            for i in range(0,len(Points)):
                #print Points[i]
                p.line([Rkms[i],Rkms[i]],y_range,'--',color = 'k')
                p.text(Rkms[i],np.mean(y_range),Points[i])#,text_align = 'center')#,angle = 3.14159265/2)
                

        if len(DOstds) > 0:
            for DOstd in DOstds:
                p.line(x_range,[DOstd,DOstd],'--',color = 'k')
                p.text(np.mean(x_range),DOstd,"DO std = "+"{:4.1f}".format(DOstd)+" mg/L")

        
    show(p)
# Out:
#     <div class="plotdiv" id="adb6e81a-3aed-4a90-8d22-2e9998412a79"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("adb6e81a-3aed-4a90-8d22-2e9998412a79");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'adb6e81a-3aed-4a90-8d22-2e9998412a79' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"8da72851-aeb4-4e66-b7d1-af8f4c502ebe":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d5c4f79-3fd0-4678-80d4-a6205a41da18","type":"Line"},{"attributes":{"callback":null},"id":"c56302c0-f1a4-4ad9-bf72-cf1cd2bcb1bc","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d979ef2c-a6d0-4fbb-8ec4-20354e1b015f","type":"ColumnDataSource"},{"attributes":{"text":{"field":"COVE 1: OUTFALL 001"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":".12"},"y":{"value":6.5}},"id":"bcaf1abd-e37c-4989-b8fe-a0240873a4c4","type":"Text"},{"attributes":{"data_source":{"id":"6f586b75-ad9e-4943-9e29-4ddac84061ee","type":"ColumnDataSource"},"glyph":{"id":"c036d2db-397f-40e6-8472-dfcd0792fbc7","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"d5ff8716-006f-449c-b335-744da395db80","type":"Text"},"selection_glyph":null},"id":"3b703ab0-27a5-4075-b223-c5c571193ae7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"56bb9f3a-cdb2-4bbb-9622-40b554e5d580","type":"ColumnDataSource"},"glyph":{"id":"b744edfd-0184-4147-8a62-924ad8878498","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"a18ba231-ff04-40a7-8939-d8a02e33cfb3","type":"Line"},"selection_glyph":null},"id":"d71e2ec6-47f7-444e-82bd-2cd65f91a494","type":"GlyphRenderer"},{"attributes":{"text":{"field":"OUTFALL 002 INLET"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"2.04"},"y":{"value":6.5}},"id":"e6b68dfc-b752-4f33-b115-faf078ead1ce","type":"Text"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.88","1.88"],"y":[0.0,13.0]}},"id":"9464e04f-d3e6-4cab-8533-f032fbff3c84","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9905fc76-91b2-4380-a5ad-1cda075c54d6","type":"ColumnDataSource"},"glyph":{"id":"35b4ae00-29ce-4166-ad21-a5f34cb95cb6","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"06908e8f-b6c8-453b-9bf6-113de47b62f4","type":"Text"},"selection_glyph":null},"id":"0922c63a-c4b5-4a01-b09a-7966d1165c1d","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac7faa3f-ab00-4750-9d47-072548df2859","type":"Line"},{"attributes":{"data_source":{"id":"76b0aad3-1e34-43e2-816c-73dcbc4da835","type":"ColumnDataSource"},"glyph":{"id":"a60d665f-9d1c-4722-b91e-0945f712fa57","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ba334096-1c2a-498c-b45b-ca8f441c7418","type":"Line"},"selection_glyph":null},"id":"55b497e7-9b9c-461a-88ff-ba4e28273275","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"e60ed2d6-0adb-491c-97b5-5f52f8cc37ce","type":"ColumnDataSource"},{"attributes":{"text":{"field":"BEGINNING"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"1.20"},"y":{"value":6.5}},"id":"c364af30-e38e-41fa-bc53-0235a6fb0af5","type":"Text"},{"attributes":{"line_color":{"field":"k"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7a621294-19ce-47a8-9896-41a7aa280bb3","type":"Line"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"39994205-def7-4253-934e-bc5ba2fe46f6","type":"Line"},{"attributes":{"data_source":{"id":"eea0bba8-5a66-4a5d-a0fb-c1c815b892d2","type":"ColumnDataSource"},"glyph":{"id":"f39ed9be-07f5-4c81-8237-2ec0794bf228","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"35774f34-1ece-467c-b741-e432832d0ed5","type":"Line"},"selection_glyph":null},"id":"692b1d76-aa3e-493d-b989-1e1246a1c51d","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"dc65518d-5bab-44b6-9fa1-a2966a62075e","type":"ColumnDataSource"},"glyph":{"id":"81edd341-574e-4ab5-a272-b7594883fff3","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ce1f784f-309f-40a2-bd60-05ff64467c93","type":"Line"},"selection_glyph":null},"id":"f63c0eda-fab6-4165-a489-37825c95f56c","type":"GlyphRen ...
#     <div class="plotdiv" id="09f0ce94-c3c7-46ad-96c2-39447e51e8c4"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("09f0ce94-c3c7-46ad-96c2-39447e51e8c4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '09f0ce94-c3c7-46ad-96c2-39447e51e8c4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b16c790e-fa13-47b1-9f34-eece31af290d":{"roots":{"references":[{"attributes":{"text":{"field":"DO std =  5.0 mg/L"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.2425},"y":{"value":5}},"id":"fe6c8849-f67e-4eaf-957d-883e3f301f18","type":"Text"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d5c4f79-3fd0-4678-80d4-a6205a41da18","type":"Line"},{"attributes":{"callback":null},"id":"c56302c0-f1a4-4ad9-bf72-cf1cd2bcb1bc","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d979ef2c-a6d0-4fbb-8ec4-20354e1b015f","type":"ColumnDataSource"},{"attributes":{"text":{"field":"COVE 1: OUTFALL 001"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":".12"},"y":{"value":6.5}},"id":"bcaf1abd-e37c-4989-b8fe-a0240873a4c4","type":"Text"},{"attributes":{"data_source":{"id":"6f586b75-ad9e-4943-9e29-4ddac84061ee","type":"ColumnDataSource"},"glyph":{"id":"c036d2db-397f-40e6-8472-dfcd0792fbc7","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"d5ff8716-006f-449c-b335-744da395db80","type":"Text"},"selection_glyph":null},"id":"3b703ab0-27a5-4075-b223-c5c571193ae7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"56bb9f3a-cdb2-4bbb-9622-40b554e5d580","type":"ColumnDataSource"},"glyph":{"id":"b744edfd-0184-4147-8a62-924ad8878498","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"a18ba231-ff04-40a7-8939-d8a02e33cfb3","type":"Line"},"selection_glyph":null},"id":"d71e2ec6-47f7-444e-82bd-2cd65f91a494","type":"GlyphRenderer"},{"attributes":{"text":{"field":"OUTFALL 002 INLET"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"2.04"},"y":{"value":6.5}},"id":"e6b68dfc-b752-4f33-b115-faf078ead1ce","type":"Text"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.88","1.88"],"y":[0.0,13.0]}},"id":"9464e04f-d3e6-4cab-8533-f032fbff3c84","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"9905fc76-91b2-4380-a5ad-1cda075c54d6","type":"ColumnDataSource"},"glyph":{"id":"35b4ae00-29ce-4166-ad21-a5f34cb95cb6","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"06908e8f-b6c8-453b-9bf6-113de47b62f4","type":"Text"},"selection_glyph":null},"id":"0922c63a-c4b5-4a01-b09a-7966d1165c1d","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ac7faa3f-ab00-4750-9d47-072548df2859","type":"Line"},{"attributes":{"data_source":{"id":"76b0aad3-1e34-43e2-816c-73dcbc4da835","type":"ColumnDataSource"},"glyph":{"id":"a60d665f-9d1c-4722-b91e-0945f712fa57","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ba334096-1c2a-498c-b45b-ca8f441c7418","type":"Line"},"selection_glyph":null},"id":"55b497e7-9b9c-461a-88ff-ba4e28273275","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"e60ed2d6-0adb-491c-97b5-5f52f8cc37ce","type":"ColumnDataSource"},{"attributes":{"text":{"field":"BEGINNING"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"1.20"},"y":{"value":6.5}},"id":"c364af30-e38e-41fa-bc53-0235a6fb0af5","type":"Text"},{"attributes":{"line_color":{"field":"k"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7a621294-19ce-47a8-9896-41a7aa280bb3","type":"Line"},{"attributes":{"data_source":{"id":"db1c9973-11c8-4f6d-831d-17fe836dd339","type":"ColumnDataSource"},"glyph":{"id":"d01c8ce1-4aed-4c26-8275-04ef4b2fb580","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"3e6baf93-2dae-4eb7-9bc3-6d7d33ece12b","type":"Line"},"selection_glyph":null},"id":"dee94ee9-52ac-42a0-99f9-5f57c4f82099","type":"GlyphRenderer"},{"attributes":{},"id":"9498cd0f-56bc-45c2-907c-a560156347ce","type":"ToolEvents"},{"attributes":{"line_color":{"value":"green"},"line_width":{"value":2.0},"x":{"field":"x"},"y":{"field":"y"}},"id":"39994205-def7-4253-934e-bc5ba2fe46f6","type":"Line"},{"attributes":{"data_source":{"id":"b07b9c48-17c0-495e-bcfa-481 ...
#     <div class="plotdiv" id="d505f8ad-44cb-453a-baf3-7c8eafdd6b03"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d505f8ad-44cb-453a-baf3-7c8eafdd6b03");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd505f8ad-44cb-453a-baf3-7c8eafdd6b03' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"930dbe65-cd80-4ecd-a512-1a82b171cb7c":{"roots":{"references":[{"attributes":{"text":{"field":"DO std =  5.0 mg/L"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"value":1.2425},"y":{"value":5}},"id":"fe6c8849-f67e-4eaf-957d-883e3f301f18","type":"Text"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0d5c4f79-3fd0-4678-80d4-a6205a41da18","type":"Line"},{"attributes":{"text":{"field":"ELM FRK"},"text_color":{"value":"black"},"x":{"field":".00"},"y":{"value":6.5}},"id":"e42754c7-735a-400e-ac28-a6c744f6d25f","type":"Text"},{"attributes":{"callback":null},"id":"c56302c0-f1a4-4ad9-bf72-cf1cd2bcb1bc","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"d979ef2c-a6d0-4fbb-8ec4-20354e1b015f","type":"ColumnDataSource"},{"attributes":{"text":{"field":"COVE 1: OUTFALL 001"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":".12"},"y":{"value":6.5}},"id":"bcaf1abd-e37c-4989-b8fe-a0240873a4c4","type":"Text"},{"attributes":{"data_source":{"id":"a3a4be5b-d2fa-407d-aeec-85a58b565e8e","type":"ColumnDataSource"},"glyph":{"id":"52a55ab9-ff54-426b-a0d7-3b3d8735e411","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"e4acfe57-968a-4f14-bf7e-c4e2263f9139","type":"Text"},"selection_glyph":null},"id":"3a95f5fe-2eb5-44c5-a3f6-baaddc1988a5","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6f586b75-ad9e-4943-9e29-4ddac84061ee","type":"ColumnDataSource"},"glyph":{"id":"c036d2db-397f-40e6-8472-dfcd0792fbc7","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"d5ff8716-006f-449c-b335-744da395db80","type":"Text"},"selection_glyph":null},"id":"3b703ab0-27a5-4075-b223-c5c571193ae7","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"56bb9f3a-cdb2-4bbb-9622-40b554e5d580","type":"ColumnDataSource"},"glyph":{"id":"b744edfd-0184-4147-8a62-924ad8878498","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"a18ba231-ff04-40a7-8939-d8a02e33cfb3","type":"Line"},"selection_glyph":null},"id":"d71e2ec6-47f7-444e-82bd-2cd65f91a494","type":"GlyphRenderer"},{"attributes":{"text":{"field":"OUTFALL 002 INLET"},"text_alpha":{"value":0.1},"text_color":{"value":"black"},"x":{"field":"2.04"},"y":{"value":6.5}},"id":"e6b68dfc-b752-4f33-b115-faf078ead1ce","type":"Text"},{"attributes":{"data_source":{"id":"0dc2b833-825c-4782-a8ac-572683d4ac78","type":"ColumnDataSource"},"glyph":{"id":"d5f7e9eb-9995-45b7-ab38-b5afe3dc99c8","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"c0b1745c-6719-4704-8e33-b58715c39789","type":"Text"},"selection_glyph":null},"id":"8cf6b812-e3d2-452d-a912-1584a5e780a9","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.88","1.88"],"y":[0.0,13.0]}},"id":"9464e04f-d3e6-4cab-8533-f032fbff3c84","type":"ColumnDataSource"},{"attributes":{"line_color":{"field":"k"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d78a8f30-292e-4d24-85b8-f454076e546a","type":"Line"},{"attributes":{"data_source":{"id":"16fe7d21-5781-481b-ae69-c491f05377c0","type":"ColumnDataSource"},"glyph":{"id":"6c7e5093-5930-446e-bab0-e9811663e8ef","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"004decd4-ac20-4c84-b26a-00d197481a9a","type":"Line"},"selection_glyph":null},"id":"4d1ab17c-4149-4fa0-b838-e97b650dbee5","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce5b45c1-7c5d-4697-a74c-fff007371e70","type":"Line"},{"attributes":{"data_source":{"id":"9905fc76-91b2-4380-a5ad-1cda075c54d6","type":"ColumnDataSource"},"glyph":{"id":"35b4ae00-29ce-4166-ad21-a5f34cb95cb6","type":"Text"},"hover_glyph":null,"nonselection_glyph":{"id":"06908e8f-b6c8-453b-9bf6-113de47b62f4","type":"Text"},"selection_glyph":null},"id":"0922c63a-c4b5-4a01-b09a-7966d1165c1d","type":"GlyphRenderer"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field ...
