# %%
import json
from pprint import pprint
from ET_Utils.WATERS_Utils import event_indexing_client
lon, lat = (-97.782752, 30.397861)  # Bull Creek in zip 78759
length_km = 5
mock_events = event_indexing_client.trace_downstream(lat, lon, length_km)
#pprint(mock_events)

# %%
import folium
fmap = folium.Map(location=[30.397861, -97.782752], zoom_start=15)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
folium.GeoJson(mock_events).add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
